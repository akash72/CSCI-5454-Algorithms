# %% [markdown]
# # Assignment 5
#
# Your Name: Akash Iyengar
#
# Collaborated With:
#
#
# > This assignment is to be completed and uploaded to
# moodle as a python3 notebook.
#
# > Submission deadlines are posted on moodle.
#
# > The questions  provided  below will ask you to either write code or
# write answers in the form of markdown.
#
# > Markdown syntax guide is here: [click here](https://github.com/adam-p/markdown-here/wiki/Markdown-Cheatsheet)
#
# > Using markdown you can typeset formulae using latex.
#
# > This way you can write nice readable answers with formulae like thus:
#
# >> The algorithm runs in time $\Theta\left(n^{2.1\log_2(\log_2( n \log^*(n)))}\right)$,
# wherein $\log^*(n)$ is the inverse _Ackerman_ function.
#
# __Double click anywhere on this box to find out how your instructor typeset it. Press Shift+Enter to go back. __

# %% [markdown]
# ## Q1: Bloom Filters (10 points)
#
# > A bloom filter is a fast set data structure that maintains a set $S$ of keys. One can insert keys into the set and test whether a given key $k$ belongs to the set. It may used in applications where the keys are ``complicated'' objects such as TCP packets or images that are expensive to compare with each other.
#
# > The data structure is an array $T$ of Booleans size $m$ with $l$ different hash functions $h_1, \ldots, h_l$.
# >> Initially, `T[i] = FALSE` for all `i`.
#
# > If a key $k$ is to be inserted
# >> We compute $i_1 = h_1(k), \ldots, i_l = h_l(k)$.
# >> We set $T[i_1] = \cdots T[i_l] = \text{TRUE}$.
#
# > __(A)__ Suppose we wish to find out if an element $k$ is a member of the set by checking if
# $T[h_1(k)], \ldots, T[h_l(k)]$ are all true. Explain whether this can lead to a *false positive* i.e,
# the approach wrongly concludes that $k$ belongs to the set when it was never inserted; or *false negative*
# i.e, the approach wrongly concludes that $k$ does not belong to the set when it does.
#
# > __(B)__ Suppose our hash functions are guaranteed to be uniform. I.e, for any randomly chosen
# key $k$, for any hash function $h_i$ and cell $j$,
# >  $$ \mathbb{P}( h_i(k) = j)  = \frac{1}{m} $$
# > If $n$ keys are chosen at random and inserted into the filter, compute that probability that any given cell $T[j]$ is set to FALSE after this.
#
# > __(C)__ Use the results from previous set to estimate the probabilisty of a false positive. I.e, some $l$ cells
# $i_1, i_2, \ldots, i_l$ are simultaneously set to TRUE.

# %% [markdown]
# **Answer (a)**
# >1. In a bloom filter there is a possiblity of getting a false positive , but there is no possiblity of getting false negative.<br/><br/>
# >2. Consider a query given for element b we check the bits at position h_1(b), h_2(b),....,h_l(b) if any of them gives 0 then is not in the set, otherwise we can conjecture that element b is in the set, which can be false sometimes.<br/><br/>
# >3. There might be a case where an element can refer to the same array position as that of an another element,in those cases the new element doesn’t change the value as 1 in its array position ,but the previous element would have set the value as 1.<br/><br/>
# >4. We can never get false negative, because its guaranteed to report correctly if it contains the item.<br/>
#
# **Answer (b)**
# >1. The probablity of an element present in the set is given by:-<br/>
# $$P(Present) = \frac{1}{m}$$
#
# >2. The probablity of an element not present in an set (i.e a element giving false is ):- <br/>
# $$ P(T[j] = False) = 1- \frac{1}{m}$$
#
# >3. If k is the number of hash functions and each has no significant correlation between each other, then the probability that the bit is not set to TRUE by any of the hash functions is<br/>
# $$ P(T[j] = False) = (1- \frac{1}{m})^k $$
#
# >4. If we have inserted n elements, the probability that a certain bit is still FALSE is<br/>
# $$ P(T[j] = False) = (1- \frac{1}{m})^{kn} $$
#
# **Answer (c)**
# >1. The Probablity of false Positive can be calculated as follows:-<br/>
#
# >2. Lets consider,<br/>
#
# >n = size of bloom filter array.<br/>
# >m = no of elements.<br/>
# >k = no of hash functions.<br/>
#
# >3. The probability that a bit ‘j’ is not set to TRUE is<br/>
# $$ (1- \frac{1}{m})^n $$
#
# >4. The above equation can be written as <br/>
# $$ e^{-\frac{km}{n}} $$
#
# >5. Hence the probability of False Positives and that all bits of new element is set to TRUE is<br/>
# $$ P = ({1-e^{-\frac{km}{n}}})^k $$
#
# >6. The right hand side is minimized for<br/>
# $$k = \ln 2 \times{ \frac{m}{n}} $$
#
# >7. Therefore the probablity of false positive is <br/>
# $$ (\frac{1}{2})^k = (0.6185)^{\frac{m}{n}} $$

# %% [markdown]
# ## Q2: Function Collision Problem (10 points)
#
# Suppose we are given a black box function $f(x,y)$ that takes in two integers and returns an integer.
# eg., $f(x,y) = (x + y^2) + (x^2 - y)$.
#
# Write an algorithm to _count_ the number of possible quadruples: $(x, y, w, z)$ such that
# $1 \leq x,y,w,z \leq n$, $x \not= w$ or $y \not= z$, and $f(x,y) = f(w,z)$.
#
# (A) Provide a deterministic algorithm without any randomization. Calculate its worst case running time and how much extra space you will need. Your algorithm must be made as efficient as possible.
#
# (B) Provide a randomized algorithm that must run in $O(n^2)$ time on the average. Calculate how much extra space will be needed for your algorithm.
#
# Clarity of your answer is very important. An answer that is hard to read/understand will not be given credit.

# %% [markdown]
# **Answer (a)**
# **ALGORITHM**
# >1. Choose all the elements and store them in list a.<br/>
# >2. Sort all the stored elements by f(x,y) <br/>
# >3. Repeat the first step and store it in a new list a2 and sort elements by f(w,z)<br/>
# >4. pair all the elements whose results are the same in both the lists that is to check the function f(x,y) = f(w,z)<br/>
#
# > The running time complexity for the O(n^2log(n)). <br/>
# > The extra space will be needed for number of quadruples which will be calculated.<br/>
#
# **Answer (b)**
# **ALGORITHM**
# >1. The first step is to inintalize an empty hash map H.<br/>
# >2. Calculate f(x,y) and instert the result as a key to the hash map H.<br/>
# >3. Insert the pair(x,y) as the value along with the key.<br/>
# >4. If f(x,y) is already in H, then insert the pair(x,y) to the corresponding key in H by chaining <br/>
# >5. Combine distinct pair to generate quadruples.<br/>
#
# >The running time of the algorithm is $\Theta\left(n^{2}\right)$ and quadruples can be obtained by pairing collection in $\Theta\left(n^{2}\right)$ + the number of quadruples generated<br/>
#
# > the extra space needed here will be for the number of quadruples.<br/>

# %% [markdown]
# ## Q3: Prove Universal Hash Function (15 points)
#
# Suppose we are interested in hashing $n$ bit keys into $m$ bit hash values to hash into a table of size
# $2^m$. We view our key  as a bit vector of $n$ bits in binary. Eg., for $n = 4$, the key $14 = \left(\begin{array}{c} 1\\ 1\\ 1\\ 0 \end{array} \right)$.
#
# The hash family is defined by random boolean matrices $H$ with $m$ rows and $n$ columns. To compute the hash function, we perform a matrix multiplication. Eg., with $m = 3$ and $n= 4$, we can have a matrix $H$ such as
#
# $$ H = \left[ \begin{array}{cccc} 0 & 1 & 0 & 1 \\
# 1 & 0 & 0 & 0 \\
# 1 & 0 & 1 & 1 \\
# \end{array} \right]$$.
#
#
# The value of the hash function $H(14)$ is now obtained by multiplying
#
# $$ \left[ \begin{array}{cccc} 0 & 1 & 0 & 1 \\
# 1 & 0 & 0 & 0 \\
# 1 & 0 & 1 & 1 \\
# \end{array} \right] \times \left( \begin{array}{c}
# 1\\
# 1\\
# 1\\
# 0\\
# \end{array} \right) $$
#
# The matrix multiplication is carried out using AND for multiplication and XOR instead of addition.
#
# (A) For a given matrix $H$ and two  keys $x, y$ that differ only in their $i^{th}$ bits, provide a condition for
# $Hx = Hy$ holding. (**Hint** It may help to play with examples where you have two numbers $x, y$ that just differ at a particular bit position. Figure out which entries in the matrix are multiplied with these bits that differ).
#
# (B) Prove that the probability that two keys $x, y$ such that $x \not= y$ collide under the random choice of a matrix $x, y$ is at most $\frac{1}{2^m}$.

# %% [markdown]
# ## Answer 3 (Expected Size: 15 lines)

# %% [markdown]
# >__SOLUTION A__: Since keys x and y are not equal ,$∃i$ bit such that $xi \not = yi $.
# >Assume if $x_i = 0,y_i = 1$.
#
# >Suppose that the bits of all the columns of matrix H , except for the ith column are computed, the condition for $h(x) = h(y)$ happens if and only if $$∀j,1 ≤ j ≤ m,h(x)_j = h(y)_j $$
#
# >__SOLUTION B__: Assume that  $x_i=0$ and $y_i=1$.
#
# >Entire  H except  the ith column is computed. Since xi = 0, the ith column of H does not contribute to h(x).
# >Over remaining choices of ith column, h(x) is fixed.
#
# >But, each of the $2^{m}$ different settings of the ith column gives a different value of h(y).
#
# >The jth bit of h(y) is given by $h(y)_j =H_{ji} +􏰄 \sum_{k \not =i} H_{jk} \times y_k $.
#
# > The value of $h(y)_{j}$ depends on the value of $A_{ji}$.
#
# >By Changing or flipping  a bit in that column, the corresponding bit in h(y) is changed.
#
# >$A_{ji}$ = 0 or 1 with equal probability.
#
# >So there is at most a $ 1/2^{m}$ chance that $h(x) = h(y)$.
